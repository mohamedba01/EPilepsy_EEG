# %%
 from google.colab import drive

drive.mount("/content/gdrive")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
data_3f=pd.read_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DATA__/DTF010.csv')

# %%
 data_3f.head()

# %%
data_3f = data_3f.drop('Unnamed: 0',1)

# %%
data_txt=pd.read_csv('/content/gdrive/MyDrive/DS PROJECT/travail fichiers textes/data_txt002.csv')

# %%
data_txtall=pd.DataFrame(columns=['ID'])

# %%
data_txtall['ID']= data_3f['ID']

# %%
data_txtall

# %%
id_2=[0]*1648

# %%
data_txt['ID']

# %%
for j in range(len(data_txt['ID'])) :
  for i in range(len(data_txtall['ID'])) :
    if data_txtall['ID'][i].startswith(data_txt['ID'][j]):
       id_2[i]= data_txt['ID'][j]

# %%
id_2

# %%
data_txtall['ID_2']=id_2

# %%
data_txtall

# %%
data_txt

# %%
data_txt = data_txt.drop('Unnamed: 0',1)

# %%
import numpy as np
#traitement age :

# %%
data_txt.age = pd.to_numeric(data_txt.age, errors='coerce')

# %%
data_txt

# %%
for ag in range(len(data_txt['age'])) :
  if  data_txt['age'].isnull()[ag] :
    print(ag)
    data_txt['age'][ag]=0
  elif data_txt['age'][ag]<0 :
    data_txt['age'][ag]=0

# %%
for ag in range(len(data_txt['age'])) :
  if data_txt['age'][ag]==0 :
    data_txt['age'][ag]=data_txt['age'].mean()

# %%
for g in range(len(data_txt['gender'])) :
  if  (data_txt['gender'][g]=='female' ) :
    #print(data_txt['gender'][g])
     data_txt['gender'][g]=0
  elif  (data_txt['gender'][g]=='male' ) :
   # print(data_txt['gender'][g])
     data_txt['gender'][g]=1
  else :
     data_txt['gender'][g]=2
   # print(data_txt['gender'][g])

# %%
for e in range(len(data_txt['egg nature'])) :
  if  (data_txt['egg nature'][e]=='normal EEG' ) :
  
     data_txt['egg nature'][e]=0
  elif  (data_txt['egg nature'][e]=='abnormal EEG' ) :

     data_txt['egg nature'][e]=1
  else :
     data_txt['egg nature'][e]=2

# %%
data_txt.HR = pd.to_numeric(data_txt.HR, errors='coerce')

# %%
for h in range(len(data_txt['HR'])) :
  if  data_txt['HR'].isnull()[h] :
    
    data_txt['HR'][h]=0

# %%
for ag in range(len(data_txt['HR'])) :
  if data_txt['HR'][ag]==0 :
    data_txt['HR'][ag]=data_txt['HR'].mean()

# %%
data_txt['HR']

# %%
data_txt

# %%
data_txtall[data_txt.columns[1:]]=0

# %%
data_txtall

# %%
for i in range(data_txtall.shape[0]) :
  for j in range(data_txt.shape[0]):
    if data_txtall.ID_2[i] == data_txt.ID[j] :
      data_txtall.loc[i,data_txtall.columns[2:]]=data_txt.loc[j,data_txt.columns[1:]]

# %%
data_txtall

# %%
data_3f

# %%
data_txtall = data_txtall.drop('ID_2',1)

# %%
data_txtall

# %%
data_3f = data_3f.drop('ID',1)

# %%
data_3f

# %%
# Merge two Dataframes on index of both the dataframes
mergedDf = data_txtall.merge(data_3f, left_index=True, right_index=True)

# %%
mergedDf

# %%
#mergedDf.to_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF030.csv')
#mergedDf.to_excel('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF030.xlsx')

# %%
#import pandas as pd
#mergedDf=pd.read_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF030.csv')

# %%
#mergedDf

# %%
#encoding

# %%
data_dummies = pd.get_dummies(mergedDf, columns=['gender','egg nature'])
data_dummies

# %%
#data_dummies.to_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF040.csv'(index=False))
#data_dummies.to_excel('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF040.xlsx'(index=False))

# %%
#correlation :

# %%
#import seaborn as sns           #'Seaborn' is a library for making statistical graphics in Python. It builds on top of matplotlib
#import matplotlib.pyplot as plt #'Pyplot' is intended for interactive plots and simple cases of programmatic plot generation

# Let's see the correlation matrix 
#plt.figure(figsize = (20,10))        # Size of the figure
#sns.heatmap(data_dummies.corr(),annot = True)

# %%
#encoded=pd.read_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/DTF040DTF030+txtDATA+targetEncoded.csv')

# %%
#encoded = encoded.drop(['Unnamed: 0','Unnamed: 0.1'],1)

# %%
data_dummies

# %%
#encoded = encoded.drop('Unnamed: 0' ,1)

# %%
import pandas as pd
import numpy as np

# %%
X = data_dummies
y = [1]*1360 +[0]*288

# %%
cor_matrix = X.corr().abs()

# %%
  print(cor_matrix)

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
print(upper_tri)

# %%
    to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
    print(); print(to_drop)

# %%
len(to_drop)

# %%
df1 = X.drop(to_drop,1)
print(); print(df1.head())

# %%
df1

# %%
#normalisation :

# %%
    import pandas as pd
    from sklearn import preprocessing

# %%
df2=df1.drop('ID',1)

# %%
#df1
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(df2)
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized

# %%
#df_normalized.to_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/X_DTF.csv')
#df_normalized.to_excel('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/X_DTF040.xlsx')
#Y.to_csv('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/Y_DTF.csv')
#Y.to_excel('/content/gdrive/MyDrive/DS PROJECT/DATAFINAl001/Y_DTF.xlsx')
